# %% [markdown]
# # __Интенсив__

# %% [markdown]
# ## __День 1. Начало работы с данными__
# ### 21 февраля

# %% [markdown]
# ### 1.1. Интерактивные ноутбуки Jupyter
# - почему удобно
# - первые шаги
# - какие недостатки
# - особенности платформы Симба

# %% [markdown]
# ### 1.2. Работа с данными в Симба
# - доступные окружения (фреймворки)
# - какое окружение выбрать для задачи
# - большие данные
# - подключение к источникам, парсинг данных

# %% [markdown]
# ### 1.3. Использование ИИ для анализа данных
# - LLM как разработчик кода
# - правильный промпт для анализа данных
# - от запроса к результату
# - продвинутые подходы к разработке

# %% [markdown]
# ### 1.4. Основы работы с изображениями и текстом
# - хранение и обработка изображений, извлечение признаков
# - работа с текстом
# - извлечение признаков из текста, изображений для решения аналитических задач

# %% [markdown]
# ## __День 2. Работа с мультимодальные данными__
# ### 28 февраля

# %% [markdown]
# ### 2.1. Глубокое обучение для работы с изображениями и текстом
# - задачи компьютерного зрения
# - задачи NLP
# - обзо моделей и подходов

# %% [markdown]
# ### 2.2. Кейс с леопардами
# - исходные данные и постановка задачи
# - применяемые подходы и фреймворки
# - итоговый результат: ИИ ассистент на технологии RAG

# %% [markdown]
# ### 2.3. Кейс со спутниками
# - варианты постановки задачи
# - оценка применимости различных моделей
# - образ конечного результата

# %% [markdown]
# ### 2.4. Финальные проекты
# - выбор проекта
# - выбор инструментария
# - итоговая презентация (опционально - с демо)
